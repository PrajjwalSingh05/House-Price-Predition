# %%
import numpy as np
import pandas as pd
import  matplotlib.pyplot as plt
from  sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.feature_selection import SelectKBest,chi2,RFE
from sklearn.tree import ExtraTreeClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split,GridSearchCV
from imblearn.over_sampling import SMOTE,ADASYN

from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import  make_pipeline,Pipeline
from sklearn.metrics import r2_score,mean_absolute_error
from sklearn.compose import ColumnTransformer
from sklearn.feature_selection import f_regression
from sklearn.metrics import confusion_matrix,classification_report

# %%
url="https://raw.githubusercontent.com/digipodium/Datasets/main/regression/ames_housing_no_missing.csv"
df=pd.read_csv(url,index_col=False)
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave  Grvl      Reg
# 1          20       RL         80.0     9600   Pave  Grvl      Reg
# 2          60       RL         68.0    11250   Pave  Grvl      IR1
# 3          70       RL         60.0     9550   Pave  Grvl      IR1
# 4          60       RL         84.0    14260   Pave  Grvl      IR1
#
#   LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub    Inside  ...        0     Gd  MnPrv        Shed
# 1         Lvl    AllPub       FR2  ...        0     Gd  MnPrv        Shed
# 2         Lvl    AllPub    Inside  ...        0     Gd  MnPrv        Shed
# 3         Lvl    AllPub    Corner  ...        0     Gd  MnPrv        Shed
# 4         Lvl    AllPub       FR2  ...        0     Gd  MnPrv        Shed
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0       0      2    2008        WD         Normal     208500
# 1       0      5    2007        WD         Normal     181500
# 2       0      9    2008        WD         Normal     223500
# 3       0      2    2006        WD        Abnorml     140000
# 4       0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]

# %%
X=df.drop(columns="SalePrice")
y=df["SalePrice"]

# %%
numeric_transformer = Pipeline(
            steps=[("imputer", SimpleImputer(strategy="median")), ("scaler", StandardScaler())]
        )

categorical_transformer = OneHotEncoder(handle_unknown="ignore")
preprocessor = ColumnTransformer(
            transformers=[
                ("numeric", numeric_transformer, X.select_dtypes(np.number).columns.tolist()),
                ("category", categorical_transformer,X.select_dtypes("object").columns.tolist()),
            ]
        )

# %%
xtrain,xtest,ytrain,ytest=train_test_split(X,y,test_size=0.2,random_state=45)

# %%
feature_selector = Pipeline(
        steps=[("preprocessor", preprocessor),
        ("feature", SelectKBest(f_regression,k=3))]
    )
feature_selector.fit(xtrain,ytrain)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('numeric',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['MSSubClass', 'LotFrontage',
#                                                    'LotArea', 'OverallQual',
#                                                    'OverallCond', 'YearBuilt',
#                                                    'YearRemodAdd', 'MasVnrArea',
#                                                    'BsmtFinSF1', 'BsmtFinSF2',
#                                                    'BsmtUnfSF', 'TotalBsmtSF',
#                                                    '1stFlrSF', '2ndFlrSF',
#                                                    'Low...
#                                                    'Neighborhood', 'Condition1',
#                                                    'Condition2', 'BldgType',
#                                                    'HouseStyle', 'RoofStyle',
#                                                    'RoofMatl', 'Exterior1st',
#                                                    'Exterior2nd', 'MasVnrType',
#                                                    'ExterQual', 'ExterCond',
#                                                    'Foundation', 'BsmtQual',
#                                                    'BsmtCond', 'BsmtExposure',
#                                                    'BsmtFinType1',
#                                                    'BsmtFinType2', 'Heating',
#                                                    'HeatingQC', 'CentralAir',
#                                                    'Electrical', ...])])),
#                 ('feature',
#                  SelectKBest(k=3,
#                              score_func=<function f_regression at 0x000002C2A1C84CA0>))])

# %%
print(feature_selector.get_feature_names_out())
# Out:
# ['numeric__OverallQual' 'numeric__GrLivArea' 'numeric__GarageCars']

# %%
model_selector = Pipeline(
        steps=[("preprocessor", preprocessor),
        ("feature", SelectKBest(f_regression,k=3)),
        ("classifier", RandomForestRegressor())]
    )
model_selector.fit(xtrain,ytrain)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('numeric',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['MSSubClass', 'LotFrontage',
#                                                    'LotArea', 'OverallQual',
#                                                    'OverallCond', 'YearBuilt',
#                                                    'YearRemodAdd', 'MasVnrArea',
#                                                    'BsmtFinSF1', 'BsmtFinSF2',
#                                                    'BsmtUnfSF', 'TotalBsmtSF',
#                                                    '1stFlrSF', '2ndFlrSF',
#                                                    'Low...
#                                                    'HouseStyle', 'RoofStyle',
#                                                    'RoofMatl', 'Exterior1st',
#                                                    'Exterior2nd', 'MasVnrType',
#                                                    'ExterQual', 'ExterCond',
#                                                    'Foundation', 'BsmtQual',
#                                                    'BsmtCond', 'BsmtExposure',
#                                                    'BsmtFinType1',
#                                                    'BsmtFinType2', 'Heating',
#                                                    'HeatingQC', 'CentralAir',
#                                                    'Electrical', ...])])),
#                 ('feature',
#                  SelectKBest(k=3,
#                              score_func=<function f_regression at 0x000002C2A1C84CA0>)),
#                 ('classifier', RandomForestRegressor())])

# %%
model_selector = Pipeline(
        steps=[("preprocessor", preprocessor),
        ("feature", SelectKBest(f_regression,k=3)),
        ("classifier", RandomForestRegressor())]
    )
model_selector.fit(xtrain,ytrain)
model_selector.fit(xtrain,ytrain)
ypred=model_selector.predict(xtest)
result=r2_score(ytest,ypred)
print(f"R2score is {result}")
# Out:
# R2score is 0.802896677623937

# %%
parms={
    "classifier__n_estimators":[50,100,150,200,250],
    'classifier__criterion':["squared_error", "absolute_error", "poisson"],
    'classifier__max_depth':[10,15,20,25,30],
    # 'classifier__min_samples_leaf':[1,2]
}
# grid=GridSearchCV(clf,parms,cv=4,n_jobs=-1,verbose=3)
# grid.fit(xtrain,ytrain)

# %%
grid=GridSearchCV(model_selector,parms,cv=4,n_jobs=-1,verbose=3)
grid.fit(xtrain,ytrain)
# Out:
# Fitting 4 folds for each of 75 candidates, totalling 300 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\machine learning\zaid sir(Digipodium)\Project\House sale\traing.ipynb Cell 11 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/machine%20learning/zaid%20sir%28Digipodium%29/Project/House%20sale/traing.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> grid=GridSearchCV(model_selector,parms,cv=4,n_jobs=-1,verbose=3)
# ----> <a href='vscode-notebook-cell:/d%3A/machine%20learning/zaid%20sir%28Digipodium%29/Project/House%20sale/traing.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> grid.fit(xtrain,ytrain)
#
# File c:\Python\lib\site-packages\sklearn\model_selection\_search.py:875, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     869     results = self._format_results(
#     870         all_candidate_params, n_splits, all_out, all_more_results
#     871     )
#     873     return results
# --> 875 self._run_search(evaluate_candidates)
#     877 # multimetric is determined here because in the case of a callable
#     878 # self.scoring the return type is only known after calling
#     879 first_test_score = all_out[0]["test_scores"]
#
# File c:\Python\lib\site-packages\sklearn\model_selection\_search.py:1379, in GridSearchCV._run_search(self, evaluate_candidates)
#    1377 def _run_search(self, evaluate_candidates):
#    1378     """Search all candidates in param_grid"""
# -> 1379     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\Python\lib\site-packages\sklearn\model_selection\_search.py:822, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     814 if self.verbose > 0:
#     815     print(
#     816         "Fitting {0} folds for each of {1} candidates,"
#     817         " totalling {2} fits".format(
#     818             n_splits, n_candidates, n_candidates * n_splits
#     819         )
#     820     )
# --> 822 out = parallel(
#     823     delayed(_fit_and_score)(
#     824         clone(base_estimator),
#     825         X,
#     826         y,
#     827         train=train,
#     828         test=test,
#     829         parameters=parameters,
#     830         split_progress=(split_idx, n_splits),
#     831         candidate_progress=(cand_idx, n_candidates),
#     832         **fit_and_score_kwargs,
#     833     )
#     834     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     835         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     836     )
#     837 )
#     839 if len(out) < 1:
#     840     raise ValueError(
#     841         "No fits were performed. "
#     842         "Was the CV iterator empty? "
#     843         "Were there no candidates?"
#     844     )
#
# File c:\Python\lib\site-packages\joblib\parallel.py:1056, in Parallel.__call__(self, iterable)
#    1053     self._iterating = False
#    1055 with self._backend.retrieval_context():
# -> 1056     self.retrieve()
#    1057 # Make sure that we get a last message telling us we are done
#    1058 elapsed_time = time.time() - self._start_time
#
# File c:\Python\lib\site-packages\joblib\parallel.py:935, in Parallel.retrieve(self)
#     933 try:
#     934     if getattr(self._backend, 'supports_timeout', False):
# --> 935         self._output.extend(job.get(timeout=self.timeout))
#     936     else:
#     937         self._output.extend(job.get())
#
# File c:\Python\lib\site-packages\joblib\_parallel_backends.py:542, in LokyBackend.wrap_future_result(future, timeout)
#     539 """Wrapper for Future.result to implement the same behaviour as
#     540 AsyncResults.get from multiprocessing."""
#     541 try:
# --> 542     return future.result(timeout=timeout)
#     543 except CfTimeoutError as e:
#     544     raise TimeoutError from e
#
# File c:\Python\lib\concurrent\futures\_base.py:440, in Future.result(self, timeout)
#     437 elif self._state == FINISHED:
#     438     return self.__get_result()
# --> 440 self._condition.wait(timeout)
#     442 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     443     raise CancelledError()
#
# File c:\Python\lib\threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:

# %%
grid.best_params_
# Out:
# {'classifier__criterion': 'absolute_error',
#  'classifier__max_depth': 10,
#  'classifier__n_estimators': 250}

# %%
Listing=[]
def extracting():
    for i in range(1,25):
# ****************Feature Seclortot**********************************************
        feature_selector = Pipeline(
            steps=[("preprocessor", preprocessor),
            ("feature", SelectKBest(f_regression,k=i))])
        feature_selector.fit(xtrain,ytrain)
 # ****************Model Seclortot**********************************************
        model_selector = Pipeline(
            steps=[("preprocessor", preprocessor),
            ("feature", SelectKBest(f_regression,k=i)),
            ("classifier", RandomForestRegressor())]
        )
        model_selector.fit(xtrain,ytrain)\
# *********************************Hyper Parametet***********************************
        grid=GridSearchCV(model_selector,parms,cv=4,n_jobs=-1,verbose=3)
        grid.fit(xtrain,ytrain)
        feature=grid.best_params_

        model=grid.best_estimator_
        ypred_model=model.predict(xtest)
        result_model=r2_score(ytest,ypred_model)
        print(f"R2score of Result Model is : {result_model}")
#****************************Result Generation ******************************
        ypred=model_selector.predict(xtest)
        result=r2_score(ytest,ypred)
        print(f"R2score is {result}")
#*********************************Working on features****************************
        xopt=feature_selector.get_feature_names_out()
        feature_selection=[]
        for x in xopt:
            feature_selection.append(x.split("__")[1])
        print(feature_selection)
        print(f"***********************--{i}******************")

# ********************Colecting Data--***********************************************
        Listing.append({
            "i":i,
            "Error":result,
            "Error_model":result_model,
            "columns":feature_selection,
            "parameter":feature
        })

# %%
# extracting()
# Out:
# Fitting 4 folds for each of 75 candidates, totalling 300 fits
# R2score of Result Model is : 0.6808031663042895
# R2score is 0.6828793417754206
# ['OverallQual']
# ***********************--1******************
# Fitting 4 folds for each of 75 candidates, totalling 300 fits
# R2score of Result Model is : 0.7691353180961717
# R2score is 0.7479018879949564
# ['OverallQual', 'GrLivArea']
# ***********************--2******************
# Fitting 4 folds for each of 75 candidates, totalling 300 fits
# R2score of Result Model is : 0.8176587464167182
# R2score is 0.7960901000515997
# ['OverallQual', 'GrLivArea', 'GarageCars']
# ***********************--3******************
# Fitting 4 folds for each of 75 candidates, totalling 300 fits
# R2score of Result Model is : 0.828524569167296
# R2score is 0.8203683122899574
# ['OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea']
# ***********************--4******************
# Fitting 4 folds for each of 75 candidates, totalling 300 fits
# R2score of Result Model is : 0.8455419306952175
# R2score is 0.8404559957738357
# ['OverallQual', 'TotalBsmtSF', 'GrLivArea', 'GarageCars', 'GarageArea']
# ***********************--5******************
# Fitting 4 folds for each of 75 candidates, totalling 300 fits
# R2score of Result Model is : 0.8429843492435352
# R2score is 0.8371254200224915
# ['OverallQual', 'TotalBsmtSF', 'GrLivArea', 'GarageCars', 'GarageArea', 'ExterQual_TA']
# ***********************--6******************
# Fitting 4 folds for each of 75 candidates, totalling 300 fits
# R2score of Result Model is : 0.8475317539660001
# R2score is 0.8447916787739924
# ['OverallQual', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'GarageCars', 'GarageArea', 'ExterQual_TA']
# ***********************--7******************
# Fitting 4 folds for each of 75 candidates, totalling 300 fits
# R2score of Result Model is : 0.8423784260290227
# R2score is 0.8492114755558888
# ['OverallQual', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'FullBath', 'GarageCars', 'GarageArea', 'ExterQual_TA']
# ***********************--8******************
# Fitting 4 folds for each of 75 candidates, totalling 300 fits
# R2score of Result Model is : 0.8477692583287874
# R2score is 0.8439659801578121
# ['OverallQual', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'FullBath', 'GarageCars', 'GarageArea', 'ExterQual_TA', 'BsmtQual_Ex']
# ***********************--9******************
# Fitting 4 folds for each of 75 candidates, totalling 300 fits
# R2score of Result Model is : 0.8497965364045672
# R2score is 0.8468674135858604
# ['OverallQual', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'FullBath', 'GarageCars', 'GarageArea', 'ExterQual_TA', 'BsmtQual_Ex', 'KitchenQual_TA']
# ***********************--10******************
# Fitting 4 folds for each of 75 candidates, totalling 300 fits
# R2score of Result Model is : 0.8457590168727878
# R2score is 0.8466409821929942
# ['OverallQual', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'GarageCars', 'GarageArea', 'ExterQual_TA', 'BsmtQual_Ex', 'KitchenQual_TA']
# ***********************--11******************
# Fitting 4 folds for each of 75 candidates, totalling 300 fits
# R2score of Result Model is : 0.8597470472654727
# R2score is 0.8595299372425054
# ['OverallQual', 'YearBuilt', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'GarageCars', 'GarageArea', 'ExterQual_TA', 'BsmtQual_Ex', 'KitchenQual_TA']
# ***********************--12******************
# Fitting 4 folds for each of 75 candidates, totalling 300 fits
# R2score of Result Model is : 0.8608821563165487
# R2score is 0.8576860168520267
# ['OverallQual', 'YearBuilt', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'GarageCars', 'GarageArea', 'ExterQual_TA', 'BsmtQual_Ex', 'KitchenQual_TA', 'GarageFinish_Unf']
# ***********************--13******************
# Fitting 4 folds for each of 75 candidates, totalling 300 fits
# R2score of Result Model is : 0.8629709180853897
# R2score is 0.8565977972857095
# ['OverallQual', 'YearBuilt', 'YearRemodAdd', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'GarageCars', 'GarageArea', 'ExterQual_TA', 'BsmtQual_Ex', 'KitchenQual_TA', 'GarageFinish_Unf']
# ***********************--14******************
# Fitting 4 folds for each of 75 candidates, totalling 300 fits
# R2score of Result Model is : 0.8618822484361778
# R2score is 0.858976612331701
# ['OverallQual', 'YearBuilt', 'YearRemodAdd', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'GarageCars', 'GarageArea', 'ExterQual_TA', 'Foundation_PConc', 'BsmtQual_Ex', 'KitchenQual_TA', 'GarageFinish_Unf']
# ***********************--15******************
# Fitting 4 folds for each of 75 candidates, totalling 300 fits
# R2score of Result Model is : 0.8620830685417925
# R2score is 0.8585418064578012
# ['OverallQual', 'YearBuilt', 'YearRemodAdd', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'GarageCars', 'GarageArea', 'ExterQual_TA', 'Foundation_PConc', 'BsmtQual_Ex', 'KitchenQual_Ex', 'KitchenQual_TA', 'GarageFinish_Unf']
# ***********************--16******************
# Fitting 4 folds for each of 75 candidates, totalling 300 fits
# R2score of Result Model is : 0.867937250630741
# R2score is 0.8617272964983632
# ['OverallQual', 'YearBuilt', 'YearRemodAdd', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'GarageCars', 'GarageArea', 'ExterQual_TA', 'Foundation_PConc', 'BsmtQual_Ex', 'BsmtQual_TA', 'KitchenQual_Ex', 'KitchenQual_TA', 'GarageFinish_Unf']
# ***********************--17******************
# Fitting 4 folds for each of 75 candidates, totalling 300 fits
# R2score of Result Model is : 0.8692019616814973
# R2score is 0.8620998310031255
# ['OverallQual', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'GarageCars', 'GarageArea', 'ExterQual_TA', 'Foundation_PConc', 'BsmtQual_Ex', 'BsmtQual_TA', 'KitchenQual_Ex', 'KitchenQual_TA', 'GarageFinish_Unf']
# ***********************--18******************
# Fitting 4 folds for each of 75 candidates, totalling 300 fits
# R2score of Result Model is : 0.8654007159593566
# R2score is 0.8617730340258472
# ['OverallQual', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'GarageCars', 'GarageArea', 'ExterQual_Gd', 'ExterQual_TA', 'Foundation_PConc', 'BsmtQual_Ex', 'BsmtQual_TA', 'KitchenQual_Ex', 'KitchenQual_TA', 'GarageFinish_Unf']
# ***********************--19******************
# Fitting 4 folds for each of 75 candidates, totalling 300 fits
# R2score of Result Model is : 0.8649123507153234
# R2score is 0.8660179082804559
# ['OverallQual', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageArea', 'ExterQual_Gd', 'ExterQual_TA', 'Foundation_PConc', 'BsmtQual_Ex', 'BsmtQual_TA', 'KitchenQual_Ex', 'KitchenQual_TA', 'GarageFinish_Unf']
# ***********************--20******************
# Fitting 4 folds for each of 75 candidates, totalling 300 fits
# R2score of Result Model is : 0.8691016511324396
# R2score is 0.8640465590407882
# ['OverallQual', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageArea', 'ExterQual_Gd', 'ExterQual_TA', 'Foundation_PConc', 'BsmtQual_Ex', 'BsmtQual_TA', 'BsmtFinType1_GLQ', 'KitchenQual_Ex', 'KitchenQual_TA', 'GarageFinish_Unf']
# ***********************--21******************
# Fitting 4 folds for each of 75 candidates, totalling 300 fits
# R2score of Result Model is : 0.8673286633442014
# R2score is 0.8692719116199721
# ['OverallQual', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageArea', 'ExterQual_Ex', 'ExterQual_Gd', 'ExterQual_TA', 'Foundation_PConc', 'BsmtQual_Ex', 'BsmtQual_TA', 'BsmtFinType1_GLQ', 'KitchenQual_Ex', 'KitchenQual_TA', 'GarageFinish_Unf']
# ***********************--22******************
# Fitting 4 folds for each of 75 candidates, totalling 300 fits
# R2score of Result Model is : 0.8749920684621015
# R2score is 0.86279821998887
# ['OverallQual', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageArea', 'ExterQual_Ex', 'ExterQual_Gd', 'ExterQual_TA', 'Foundation_PConc', 'BsmtQual_Ex', 'BsmtQual_TA', 'BsmtFinType1_GLQ', 'HeatingQC_Ex', 'KitchenQual_Ex', 'KitchenQual_TA', 'GarageFinish_Unf']
# ***********************--23******************
# Fitting 4 folds for each of 75 candidates, totalling 300 fits
# R2score of Result Model is : 0.8749886221586798
# R2score is 0.8653423657665856
# ['OverallQual', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageArea', 'ExterQual_Ex', 'ExterQual_Gd', 'ExterQual_TA', 'Foundation_PConc', 'BsmtQual_Ex', 'BsmtQual_TA', 'BsmtFinType1_GLQ', 'HeatingQC_Ex', 'KitchenQual_Ex', 'KitchenQual_TA', 'GarageFinish_Fin', 'GarageFinish_Unf']
# ***********************--24******************

# %%
ls=pd.DataFrame(Listing)
print(ls)
# Out:
#      i     Error  Error_model  \
# 0    1  0.682879     0.680803
# 1    2  0.747902     0.769135
# 2    3  0.796090     0.817659
# 3    4  0.820368     0.828525
# 4    5  0.840456     0.845542
# 5    6  0.837125     0.842984
# 6    7  0.844792     0.847532
# 7    8  0.849211     0.842378
# 8    9  0.843966     0.847769
# 9   10  0.846867     0.849797
# 10  11  0.846641     0.845759
# 11  12  0.859530     0.859747
# 12  13  0.857686     0.860882
# 13  14  0.856598     0.862971
# 14  15  0.858977     0.861882
# 15  16  0.858542     0.862083
# 16  17  0.861727     0.867937
# 17  18  0.862100     0.869202
# 18  19  0.861773     0.865401
# 19  20  0.866018     0.864912
# 20  21  0.864047     0.869102
# 21  22  0.869272     0.867329
# 22  23  0.862798     0.874992
# 23  24  0.865342     0.874989
#
#                                               columns  \
# 0                                       [OverallQual]
# 1                            [OverallQual, GrLivArea]
# 2                [OverallQual, GrLivArea, GarageCars]
# 3    [OverallQual, GrLivArea, GarageCars, GarageArea]
# 4   [OverallQual, TotalBsmtSF, GrLivArea, GarageCa...
# 5   [OverallQual, TotalBsmtSF, GrLivArea, GarageCa...
# 6   [OverallQual, TotalBsmtSF, 1stFlrSF, GrLivArea...
# 7   [OverallQual, TotalBsmtSF, 1stFlrSF, GrLivArea...
# 8   [OverallQual, TotalBsmtSF, 1stFlrSF, GrLivArea...
# 9   [OverallQual, TotalBsmtSF, 1stFlrSF, GrLivArea...
# 10  [OverallQual, TotalBsmtSF, 1stFlrSF, GrLivArea...
# 11  [OverallQual, YearBuilt, TotalBsmtSF, 1stFlrSF...
# 12  [OverallQual, YearBuilt, TotalBsmtSF, 1stFlrSF...
# 13  [OverallQual, YearBuilt, YearRemodAdd, TotalBs...
# 14  [OverallQual, YearBuilt, YearRemodAdd, TotalBs...
# 15  [OverallQual, YearBuilt, YearRemodAdd, TotalBs...
# 16  [OverallQual, YearBuilt, YearRemodAdd, TotalBs...
# 17  [OverallQual, YearBuilt, YearRemodAdd, MasVnrA...
# 18  [OverallQual, YearBuilt, YearRemodAdd, MasVnrA...
# 19  [OverallQual, YearBuilt, YearRemodAdd, MasVnrA...
# 20  [OverallQual, YearBuilt, YearRemodAdd, MasVnrA...
# 21  [OverallQual, YearBuilt, YearRemodAdd, MasVnrA...
# 22  [OverallQual, YearBuilt, YearRemodAdd, MasVnrA...
# 23  [OverallQual, YearBuilt, YearRemodAdd, MasVnrA...
#
#                                             parameter
# 0   {'classifier__criterion': 'absolute_error', 'c...
# 1   {'classifier__criterion': 'absolute_error', 'c...
# 2   {'classifier__criterion': 'absolute_error', 'c...
# 3   {'classifier__criterion': 'absolute_error', 'c...
# 4   {'classifier__criterion': 'poisson', 'classifi...
# 5   {'classifier__criterion': 'poisson', 'classifi...
# 6   {'classifier__criterion': 'poisson', 'classifi...
# 7   {'classifier__criterion': 'squared_error', 'cl...
# 8   {'classifier__criterion': 'poisson', 'classifi...
# 9   {'classifier__criterion': 'poisson', 'classifi...
# 10  {'classifier__criterion': 'absolute_error', 'c...
# 11  {'classifier__criterion': 'absolute_error', 'c...
# 12  {'classifier__criterion': 'absolute_error', 'c...
# 13  {'classifier__criterion': 'absolute_error', 'c...
# 14  {'classifier__criterion': 'absolute_error', 'c...
# 15  {'classifier__criterion': 'absolute_error', 'c...
# 16  {'classifier__criterion': 'poisson', 'classifi...
# 17  {'classifier__criterion': 'poisson', 'classifi...
# 18  {'classifier__criterion': 'absolute_error', 'c...
# 19  {'classifier__criterion': 'poisson', 'classifi...
# 20  {'classifier__criterion': 'absolute_error', 'c...
# 21  {'classifier__criterion': 'poisson', 'classifi...
# 22  {'classifier__criterion': 'poisson', 'classifi...
# 23  {'classifier__criterion': 'poisson', 'classifi...

# %%
# ls.to_csv('raw_data.csv', index=False)

# %%
model_selector = Pipeline(
        steps=[("preprocessor", preprocessor),
        ("feature", SelectKBest(f_regression,k=3)),
        ("classifier", RandomForestRegressor())]
    )
model_selector.fit(xtrain,ytrain)
model_selector.fit(xtrain,ytrain)
ypred=model_selector.predict(xtest)
result=r2_score(ytest,ypred)
print(f"R2score is {result}")
# Out:
# R2score is 0.8018320624839805

# %%
data=pd.read_csv("raw_data.csv")

# %%
data.head(23)
# Out:
#      i     Error  Error_model  \
# 0    1  0.682879     0.680803
# 1    2  0.747902     0.769135
# 2    3  0.796090     0.817659
# 3    4  0.820368     0.828525
# 4    5  0.840456     0.845542
# 5    6  0.837125     0.842984
# 6    7  0.844792     0.847532
# 7    8  0.849211     0.842378
# 8    9  0.843966     0.847769
# 9   10  0.846867     0.849797
# 10  11  0.846641     0.845759
# 11  12  0.859530     0.859747
# 12  13  0.857686     0.860882
# 13  14  0.856598     0.862971
# 14  15  0.858977     0.861882
# 15  16  0.858542     0.862083
# 16  17  0.861727     0.867937
# 17  18  0.862100     0.869202
# 18  19  0.861773     0.865401
# 19  20  0.866018     0.864912
# 20  21  0.864047     0.869102
# 21  22  0.869272     0.867329
# 22  23  0.862798     0.874992
#
#                                               columns  \
# 0                                     ['OverallQual']
# 1                        ['OverallQual', 'GrLivArea']
# 2          ['OverallQual', 'GrLivArea', 'GarageCars']
# 3   ['OverallQual', 'GrLivArea', 'GarageCars', 'Ga...
# 4   ['OverallQual', 'TotalBsmtSF', 'GrLivArea', 'G...
# 5   ['OverallQual', 'TotalBsmtSF', 'GrLivArea', 'G...
# 6   ['OverallQual', 'TotalBsmtSF', '1stFlrSF', 'Gr...
# 7   ['OverallQual', 'TotalBsmtSF', '1stFlrSF', 'Gr...
# 8   ['OverallQual', 'TotalBsmtSF', '1stFlrSF', 'Gr...
# 9   ['OverallQual', 'TotalBsmtSF', '1stFlrSF', 'Gr...
# 10  ['OverallQual', 'TotalBsmtSF', '1stFlrSF', 'Gr...
# 11  ['OverallQual', 'YearBuilt', 'TotalBsmtSF', '1...
# 12  ['OverallQual', 'YearBuilt', 'TotalBsmtSF', '1...
# 13  ['OverallQual', 'YearBuilt', 'YearRemodAdd', '...
# 14  ['OverallQual', 'YearBuilt', 'YearRemodAdd', '...
# 15  ['OverallQual', 'YearBuilt', 'YearRemodAdd', '...
# 16  ['OverallQual', 'YearBuilt', 'YearRemodAdd', '...
# 17  ['OverallQual', 'YearBuilt', 'YearRemodAdd', '...
# 18  ['OverallQual', 'YearBuilt', 'YearRemodAdd', '...
# 19  ['OverallQual', 'YearBuilt', 'YearRemodAdd', '...
# 20  ['OverallQual', 'YearBuilt', 'YearRemodAdd', '...
# 21  ['OverallQual', 'YearBuilt', 'YearRemodAdd', '...
# 22  ['OverallQual', 'YearBuilt', 'YearRemodAdd', '...
#
#                                             parameter
# 0   {'classifier__criterion': 'absolute_error', 'c...
# 1   {'classifier__criterion': 'absolute_error', 'c...
# 2   {'classifier__criterion': 'absolute_error', 'c...
# 3   {'classifier__criterion': 'absolute_error', 'c...
# 4   {'classifier__criterion': 'poisson', 'classifi...
# 5   {'classifier__criterion': 'poisson', 'classifi...
# 6   {'classifier__criterion': 'poisson', 'classifi...
# 7   {'classifier__criterion': 'squared_error', 'cl...
# 8   {'classifier__criterion': 'poisson', 'classifi...
# 9   {'classifier__criterion': 'poisson', 'classifi...
# 10  {'classifier__criterion': 'absolute_error', 'c...
# 11  {'classifier__criterion': 'absolute_error', 'c...
# 12  {'classifier__criterion': 'absolute_error', 'c...
# 13  {'classifier__criterion': 'absolute_error', 'c...
# 14  {'classifier__criterion': 'absolute_error', 'c...
# 15  {'classifier__criterion': 'absolute_error', 'c...
# 16  {'classifier__criterion': 'poisson', 'classifi...
# 17  {'classifier__criterion': 'poisson', 'classifi...
# 18  {'classifier__criterion': 'absolute_error', 'c...
# 19  {'classifier__criterion': 'poisson', 'classifi...
# 20  {'classifier__criterion': 'absolute_error', 'c...
# 21  {'classifier__criterion': 'poisson', 'classifi...
# 22  {'classifier__criterion': 'poisson', 'classifi...

# %%
print(df.columns.tolist())
# Out:
# ['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice']

# %%
cols1=['OverallQual', 'YearBuilt', 'YearRemodAdd', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'FullBath','TotRmsAbvGrd', 'GarageCars', 'GarageArea', 'ExterQual', 'Foundation', 'BsmtQual',  'KitchenQual', 'GarageFinish']

# %%
X = df[cols1]
xtrain,xtest,ytrain,ytest=train_test_split(X, y ,test_size=0.2,random_state=45)

# %%
xtrain.head()
# Out:
#       OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  GrLivArea  \
# 1075            7       1940          1984          800       960       1740
# 372             6       1984          1984          744       752        752
# 502             5       1965          1965         1214      1214       1214
# 924             6       1980          1980         1686      1686       1686
# 662             6       1968          1968         1392      1392       1392
#
#       FullBath  TotRmsAbvGrd  GarageCars  GarageArea ExterQual Foundation  \
# 1075         1             6           1         240        TA     CBlock
# 372          1             4           1         264        TA     CBlock
# 502          1             6           2         461        TA     CBlock
# 924          2             7           2         612        TA     CBlock
# 662          1             5           2         576        TA     CBlock
#
#      BsmtQual KitchenQual GarageFinish
# 1075       TA          TA          Unf
# 372        Gd          TA          Unf
# 502        TA          TA          Unf
# 924        Gd          TA          Unf
# 662        Fa          TA          RFn

# %%
numeric_transformer = Pipeline(steps=[("imputer", SimpleImputer(strategy="median")), ("scaler", StandardScaler())])

categorical_transformer = OneHotEncoder(handle_unknown="ignore")
preprocessor = ColumnTransformer(
            transformers=[
                ("numeric", numeric_transformer, X.select_dtypes(np.number).columns.tolist()),
                ("category", categorical_transformer,X.select_dtypes("object").columns.tolist())])
model_selector_random = Pipeline(
        steps=[("preprocessor", preprocessor),
        ("classifier", RandomForestRegressor())])

# %%
model_selector_random.fit(xtrain,ytrain)
ypred=model_selector_random.predict(xtest)
result=r2_score(ytest,ypred)
print(f"R2score is {result}")
# Out:
# R2score is 0.855963468772047

# %%
model_selector_random
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('numeric',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['OverallQual', 'YearBuilt',
#                                                    'YearRemodAdd',
#                                                    'TotalBsmtSF', '1stFlrSF',
#                                                    'GrLivArea', 'FullBath',
#                                                    'TotRmsAbvGrd', 'GarageCars',
#                                                    'GarageArea']),
#                                                  ('category',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['ExterQual', 'Foundation',
#                                                    'BsmtQual', 'KitchenQual',
#                                                    'GarageFinish'])])),
#                 ('classifier', RandomForestRegressor())])

# %%
xtrain.columns.tolist()
# Out:
# ['OverallQual',
#  'YearBuilt',
#  'YearRemodAdd',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  'GrLivArea',
#  'FullBath',
#  'TotRmsAbvGrd',
#  'GarageCars',
#  'GarageArea',
#  'ExterQual',
#  'Foundation',
#  'BsmtQual',
#  'KitchenQual',
#  'GarageFinish']

# %%
model_selector_random.fit(xtrain,ytrain)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('numeric',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['OverallQual', 'YearBuilt',
#                                                    'YearRemodAdd',
#                                                    'TotalBsmtSF', '1stFlrSF',
#                                                    'GrLivArea', 'FullBath',
#                                                    'TotRmsAbvGrd', 'GarageCars',
#                                                    'GarageArea']),
#                                                  ('category',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['ExterQual', 'Foundation',
#                                                    'BsmtQual', 'KitchenQual',
#                                                    'GarageFinish'])])),
#                 ('classifier', RandomForestRegressor())])

# %%
model_selector_random.get_params()
# Out:
# {'memory': None,
#  'steps': [('preprocessor',
#    ColumnTransformer(transformers=[('numeric',
#                                     Pipeline(steps=[('imputer',
#                                                      SimpleImputer(strategy='median')),
#                                                     ('scaler', StandardScaler())]),
#                                     ['OverallQual', 'YearBuilt', 'YearRemodAdd',
#                                      'TotalBsmtSF', '1stFlrSF', 'GrLivArea',
#                                      'FullBath', 'TotRmsAbvGrd', 'GarageCars',
#                                      'GarageArea']),
#                                    ('category',
#                                     OneHotEncoder(handle_unknown='ignore'),
#                                     ['ExterQual', 'Foundation', 'BsmtQual',
#                                      'KitchenQual', 'GarageFinish'])])),
#   ('classifier', RandomForestRegressor())],
#  'verbose': False,
#  'preprocessor': ColumnTransformer(transformers=[('numeric',
#                                   Pipeline(steps=[('imputer',
#                                                    SimpleImputer(strategy='median')),
#                                                   ('scaler', StandardScaler())]),
#                                   ['OverallQual', 'YearBuilt', 'YearRemodAdd',
#                                    'TotalBsmtSF', '1stFlrSF', 'GrLivArea',
#                                    'FullBath', 'TotRmsAbvGrd', 'GarageCars',
#                                    'GarageArea']),
#                                  ('category',
#                                   OneHotEncoder(handle_unknown='ignore'),
#                                   ['ExterQual', 'Foundation', 'BsmtQual',
#                                    'KitchenQual', 'GarageFinish'])]),
#  'classifier': RandomForestRegressor(),
#  'preprocessor__n_jobs': None,
#  'preprocessor__remainder': 'drop',
#  'preprocessor__sparse_threshold': 0.3,
#  'preprocessor__transformer_weights': None,
#  'preprocessor__transformers': [('numeric',
#    Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                    ('scaler', StandardScaler())]),
#    ['OverallQual',
#     'YearBuilt',
#     'YearRemodAdd',
#     'TotalBsmtSF',
#     '1stFlrSF',
#     'GrLivArea',
#     'FullBath',
#     'TotRmsAbvGrd',
#     'GarageCars',
#     'GarageArea']),
#   ('category',
#    OneHotEncoder(handle_unknown='ignore'),
#    ['ExterQual', 'Foundation', 'BsmtQual', 'KitchenQual', 'GarageFinish'])],
#  'preprocessor__verbose': False,
#  'preprocessor__verbose_feature_names_out': True,
#  'preprocessor__numeric': Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                  ('scaler', StandardScaler())]),
#  'preprocessor__category': OneHotEncoder(handle_unknown='ignore'),
#  'preprocessor__numeric__memory': None,
#  'preprocessor__numeric__steps': [('imputer',
#    SimpleImputer(strategy='median')),
#   ('scaler', StandardScaler())],
#  'preprocessor__numeric__verbose': False,
#  'preprocessor__numeric__imputer': SimpleImputer(strategy='median'),
#  'preprocessor__numeric__scaler': StandardScaler(),
#  'preprocessor__numeric__imputer__add_indicator': False,
#  'preprocessor__numeric__imputer__copy': True,
#  'preprocessor__numeric__imputer__fill_value': None,
#  'preprocessor__numeric__imputer__missing_values': nan,
#  'preprocessor__numeric__imputer__strategy': 'median',
#  'preprocessor__numeric__imputer__verbose': 'deprecated',
#  'preprocessor__numeric__scaler__copy': True,
#  'preprocessor__numeric__scaler__with_mean': True,
#  'preprocessor__numeric__scaler__with_std': True,
#  'preprocessor__category__categories': 'auto',
#  'preprocessor__category__drop': None,
#  'preprocessor__category__dtype': numpy.float64,
#  'preprocessor__category__handle_unknown': 'ignore',
#  'preprocessor__category__max_categories': None,
#  'preprocessor__category__min_frequency': None,
#  'preprocessor__category__sparse': True,
#  'classifier__bootstrap': True,
#  'classifier__ccp_alpha': 0.0,
#  'classifier__criterion': 'squared_error',
#  'classifier__max_depth': None,
#  'classifier__max_features': 1.0,
#  'classifier__max_leaf_nodes': None,
#  'classifier__max_samples': None,
#  'classifier__min_impurity_decrease': 0.0,
#  'classifier__min_samples_leaf': 1,
#  'classifier__min_samples_split': 2,
#  'classifier__min_weight_fraction_leaf': 0.0,
#  'classifier__n_estimators': 100,
#  'classifier__n_jobs': None,
#  'classifier__oob_score': False,
#  'classifier__random_state': None,
#  'classifier__verbose': 0,
#  'classifier__warm_start': False}
